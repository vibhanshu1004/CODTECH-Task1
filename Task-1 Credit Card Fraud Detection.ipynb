# %%
import numpy as np
import pandas as pd

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25838 entries, 0 to 25837
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    25838 non-null  int64
#  1   V1      25838 non-null  float64
#  2   V2      25838 non-null  float64
#  3   V3      25837 non-null  float64
#  4   V4      25837 non-null  float64
#  5   V5      25837 non-null  float64
#  6   V6      25837 non-null  float64
#  7   V7      25837 non-null  float64
#  8   V8      25837 non-null  float64
#  9   V9      25837 non-null  float64
#  10  V10     25837 non-null  float64
#  11  V11     25837 non-null  float64
#  12  V12     25837 non-null  float64
#  13  V13     25837 non-null  float64
#  14  V14     25837 non-null  float64
#  15  V15     25837 non-null  float64
#  16  V16     25837 non-null  float64
#  17  V17     25837 non-null  float64
#  18  V18     25837 non-null  float64
#  19  V19     25837 non-null  float64
#  20  V20     25837 non-null  float64
#  21  V21     25837 non-null  float64
#  22  V22     25837 non-null  float64
#  23  V23     25837 non-null  float64
#  24  V24     25837 non-null  float64
#  25  V25     25837 non-null  float64
#  26  V26     25837 non-null  float64
#  27  V27     25837 non-null  float64
#  28  V28     25837 non-null  float64
#  29  Amount  25837 non-null  float64
#  30  Class   25837 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 6.1 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    25749
# 1.0       88
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data['Class']==1]

# %%
fraud['Class']
# Out:
# 541      1.0
# 623      1.0
# 4920     1.0
# 6108     1.0
# 6329     1.0
#         ...
# 18773    1.0
# 18809    1.0
# 20198    1.0
# 23308    1.0
# 23422    1.0
# Name: Class, Length: 88, dtype: float64

# %%
legit.Amount.describe()
# Out:
# count    25749.000000
# mean        75.726227
# std        219.488324
# min          0.000000
# 25%          6.200000
# 50%         18.960000
# 75%         67.500000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      88.000000
# mean      100.010000
# std       265.845031
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    19380.491087 -0.197045  0.145743   0.767372  0.208854 -0.174420
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.088572 -0.100712  0.011278  0.453641  ...  0.039986 -0.039570
# 1.0   -2.487080 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.131409 -0.038716  0.012076  0.128670  0.022883  0.010424  0.003824
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.179760  0.856336  0.100578
#
#            Amount
# Class
# 0.0     75.726227
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_df = pd.concat([legit_sample,fraud],axis=0)

# %%
new_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 3233    2798 -0.416184  0.598640  1.188603 -2.092818  0.045647 -1.319317
# 4369    3763  1.322193 -0.338445  0.729055 -0.640537 -0.696066 -0.173493
# 20394  31010 -0.204149  0.935040  0.797376  0.968054  0.431777  0.341473
# 20937  31363  1.312591  0.077230 -1.292059 -0.483715  2.139937  3.181316
# 17810  28932  1.034998  0.064603  0.418749  1.056070 -0.008785  0.431081
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 3233   1.011039 -0.255301  0.703409  ...  0.114666  0.627161 -0.271867
# 4369  -0.741074 -0.054667  0.072749  ... -0.152836 -0.263982  0.149198
# 20394  0.636392  0.021289 -0.414404  ...  0.201135  0.641421 -0.158038
# 20937 -0.505961  0.805039 -0.073990  ... -0.343094 -1.148139  0.095887
# 17810 -0.155967  0.256932 -0.202735  ...  0.157999  0.441574 -0.051304
#
#             V24       V25       V26       V27       V28  Amount  Class
# 3233   0.515345 -0.016253 -0.866379  0.229122 -0.023825    1.00    0.0
# 4369  -0.025662  0.142513 -0.511778  0.003266  0.005414   10.19    0.0
# 20394 -0.770641 -0.552354 -0.212614  0.116924  0.169902   40.00    0.0
# 20937  0.946086  0.369966  0.110699 -0.021706  0.023518    1.29    0.0
# 17810 -0.285432  0.410002 -0.290003  0.043258  0.012523   37.00    0.0
#
# [5 rows x 31 columns]

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0     88
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    19288.829268 -0.206699  0.134787   0.749736  0.213925 -0.150898
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.209833 -0.047036 -0.033080  0.405309  ...  0.029329 -0.027114
# 1.0   -2.487080 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.110043 -0.034215 -0.015111  0.132394  0.035842  0.000024  0.004869
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.179760  0.856336  0.100578
#
#            Amount
# Class
# 0.0     83.085589
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %%
X = new_df.drop(columns='Class', axis=1)
Y = new_df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Model Training - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train_scaled, Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
# accuracy on training data
X_train_prediction = model.predict(X_train_scaled)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9827586206896551

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test_scaled)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9913793103448276

# %% [markdown]
# Model - KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled,Y_train)
y_knn=knn.predict(X_test_scaled)

#metrics evaluation
print(accuracy_score(Y_test,y_knn))
# Out:
# 0.9655172413793104

# %% [markdown]
# Model - Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(random_state=3)
rf.fit(X_train_scaled,Y_train)
y_rf=rf.predict(X_test_scaled)

# %%
print(accuracy_score(Y_test,y_rf))
# Out:
# 0.9913793103448276
